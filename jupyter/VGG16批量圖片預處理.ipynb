# %%
# load image and preprocess it with vgg16 structure
from keras.utils.image_utils import load_img,img_to_array
from keras.applications.vgg16 import VGG16,preprocess_input
import numpy as np

model_vgg = VGG16(weights='imagenet',include_top=False)
# define a method to load and preprocess the image
def modelProcess(img_path, model):
    img = load_img(img_path,target_size=(224,224))
    img = img_to_array(img)
    x = np.expand_dims(img,axis=0)
    x = preprocess_input(x)
    x_vgg = model.predict(x)
    x_vgg = x_vgg.reshape(1,25088)
    
    return x_vgg

def flatten(name):
    # list file names if the training datasets
    import os
    folder = f'dataset/data_vgg/{name}'
    dirs = os.listdir(folder)
    # generate path for the images
    img_path = []
    for i in dirs:
        if os.path.splitext(i)[1] == '.jpg':
            img_path.append(i)
    img_path = [folder + '//' + i for i in img_path]

    # preprocess multiple images
    features = np.zeros([len(img_path),25088])
    for i in range(len(img_path)):
        features_i = modelProcess(img_path[i],model_vgg)
        print('preprocessed:',img_path[i])
        features[i] = features_i
    
    return features

features1 = flatten('cat')
features2 = flatten('dog')
# label the results
print(features1.shape,features2.shape)
y1 = np.zeros(300)
y2 = np.ones(300)

# generate the training data
X = np.concatenate((features1,features2), axis=0)
y = np.concatenate((y1,y2), axis=0)
y = y.reshape(-1,1)
print(X.shape, y.shape)
# Out:
# 1/1 [==============================] - 0s 297ms/step
# preprocessed: dataset/data_vgg/cat//cat.1.jpg
# 1/1 [==============================] - 0s 154ms/step
# preprocessed: dataset/data_vgg/cat//cat.10.jpg
# 1/1 [==============================] - 0s 150ms/step
# preprocessed: dataset/data_vgg/cat//cat.100.jpg
# 1/1 [==============================] - 0s 149ms/step
# preprocessed: dataset/data_vgg/cat//cat.101.jpg
# 1/1 [==============================] - 0s 148ms/step
# preprocessed: dataset/data_vgg/cat//cat.102.jpg
# 1/1 [==============================] - 0s 148ms/step
# preprocessed: dataset/data_vgg/cat//cat.103.jpg
# 1/1 [==============================] - 0s 150ms/step
# preprocessed: dataset/data_vgg/cat//cat.104.jpg
# 1/1 [==============================] - 0s 159ms/step
# preprocessed: dataset/data_vgg/cat//cat.105.jpg
# 1/1 [==============================] - 0s 147ms/step
# preprocessed: dataset/data_vgg/cat//cat.106.jpg
# 1/1 [==============================] - 0s 151ms/step
# preprocessed: dataset/data_vgg/cat//cat.107.jpg
# 1/1 [==============================] - 0s 150ms/step
# preprocessed: dataset/data_vgg/cat//cat.108.jpg
# 1/1 [==============================] - 0s 151ms/step
# preprocessed: dataset/data_vgg/cat//cat.109.jpg
# 1/1 [==============================] - 0s 154ms/step
# preprocessed: dataset/data_vgg/cat//cat.11.jpg
# 1/1 [==============================] - 0s 152ms/step
# preprocessed: dataset/data_vgg/cat//cat.110.jpg
# 1/1 [==============================] - 0s 154ms/step
# preprocessed: dataset/data_vgg/cat//cat.111.jpg
# 1/1 [==============================] - 0s 153ms/step
# preprocessed: dataset/data_vgg/cat//cat.112.jpg
# 1/1 [==============================] - 0s 154ms/step
# preprocessed: dataset/data_vgg/cat//cat.113.jpg
# 1/1 [==============================] - 0s 155ms/step
# preprocessed: dataset/data_vgg/cat//cat.114.jpg
# 1/1 [==============================] - 0s 155ms/step
# preprocessed: dataset/data_vgg/cat//cat.115.jpg
# 1/1 [==============================] - 0s 156ms/step
# preprocessed: dataset/data_vgg/cat//cat.116.jpg
# 1/1 [==============================] - 0s 167ms/step
# preprocessed: dataset/data_vgg/cat//cat.117.jpg
# 1/1 [==============================] - 0s 161ms/step
# preprocessed: dataset/data_vgg/cat//cat.118.jpg
# 1/1 [==============================] - 0s 168ms/step
# preprocessed: dataset/data_vgg/cat//cat.119.jpg
# 1/1 [==============================] - 0s 174ms/step
# preprocessed: dataset/data_vgg/cat//cat.12.jpg
# 1/1 [==============================] - 0s 181ms/step
# preprocessed: dataset/data_vgg/cat//cat.120.jpg
# 1/1 [==============================] - 0s 156ms/step
# preprocessed: dataset/data_vgg/cat//cat.121.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/cat//cat.122.jpg
# 1/1 [==============================] - 0s 152ms/step
# preprocessed: dataset/data_vgg/cat//cat.123.jpg
# 1/1 [==============================] - 0s 151ms/step
# preprocessed: dataset/data_vgg/cat//cat.124.jpg
# 1/1 [==============================] - 0s 154ms/step
# preprocessed: dataset/data_vgg/cat//cat.125.jpg
# 1/1 [==============================] - 0s 151ms/step
# preprocessed: dataset/data_vgg/cat//cat.126.jpg
# 1/1 [==============================] - 0s 151ms/step
# preprocessed: dataset/data_vgg/cat//cat.127.jpg
# 1/1 [==============================] - 0s 154ms/step
# preprocessed: dataset/data_vgg/cat//cat.128.jpg
# 1/1 [==============================] - 0s 154ms/step
# preprocessed: dataset/data_vgg/cat//cat.129.jpg
# 1/1 [==============================] - 0s 150ms/step
# preprocessed: dataset/data_vgg/cat//cat.13.jpg
# 1/1 [==============================] - 0s 171ms/step
# preprocessed: dataset/data_vgg/cat//cat.130.jpg
# 1/1 [==============================] - 0s 165ms/step
# preprocessed: dataset/data_vgg/cat//cat.131.jpg
# 1/1 [==============================] - 0s 161ms/step
# preprocessed: dataset/data_vgg/cat//cat.132.jpg
# 1/1 [==============================] - 0s 156ms/step
# preprocessed: dataset/data_vgg/cat//cat.133.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/cat//cat.134.jpg
# 1/1 [==============================] - 0s 241ms/step
# preprocessed: dataset/data_vgg/cat//cat.135.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/cat//cat.136.jpg
# 1/1 [==============================] - 0s 235ms/step
# preprocessed: dataset/data_vgg/cat//cat.137.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/cat//cat.138.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/cat//cat.139.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/cat//cat.14.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/cat//cat.140.jpg
# 1/1 [==============================] - 0s 234ms/step
# preprocessed: dataset/data_vgg/cat//cat.141.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/cat//cat.142.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/cat//cat.143.jpg
# 1/1 [==============================] - 0s 243ms/step
# preprocessed: dataset/data_vgg/cat//cat.144.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/cat//cat.145.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/cat//cat.146.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/cat//cat.147.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/cat//cat.148.jpg
# 1/1 [==============================] - 0s 240ms/step
# preprocessed: dataset/data_vgg/cat//cat.149.jpg
# 1/1 [==============================] - 0s 238ms/step
# preprocessed: dataset/data_vgg/cat//cat.15.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/cat//cat.150.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/cat//cat.151.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/cat//cat.152.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/cat//cat.153.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/cat//cat.154.jpg
# 1/1 [==============================] - 0s 242ms/step
# preprocessed: dataset/data_vgg/cat//cat.155.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/cat//cat.156.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/cat//cat.157.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/cat//cat.158.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/cat//cat.159.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/cat//cat.16.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/cat//cat.160.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/cat//cat.161.jpg
# 1/1 [==============================] - 0s 238ms/step
# preprocessed: dataset/data_vgg/cat//cat.162.jpg
# 1/1 [==============================] - 0s 239ms/step
# preprocessed: dataset/data_vgg/cat//cat.163.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/cat//cat.164.jpg
# 1/1 [==============================] - 0s 219ms/step
# preprocessed: dataset/data_vgg/cat//cat.165.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/cat//cat.166.jpg
# 1/1 [==============================] - 0s 258ms/step
# preprocessed: dataset/data_vgg/cat//cat.167.jpg
# 1/1 [==============================] - 0s 243ms/step
# preprocessed: dataset/data_vgg/cat//cat.168.jpg
# 1/1 [==============================] - 0s 224ms/step
# preprocessed: dataset/data_vgg/cat//cat.169.jpg
# 1/1 [==============================] - 0s 239ms/step
# preprocessed: dataset/data_vgg/cat//cat.17.jpg
# 1/1 [==============================] - 0s 264ms/step
# preprocessed: dataset/data_vgg/cat//cat.170.jpg
# 1/1 [==============================] - 0s 258ms/step
# preprocessed: dataset/data_vgg/cat//cat.171.jpg
# 1/1 [==============================] - 0s 260ms/step
# preprocessed: dataset/data_vgg/cat//cat.172.jpg
# 1/1 [==============================] - 0s 257ms/step
# preprocessed: dataset/data_vgg/cat//cat.173.jpg
# 1/1 [==============================] - 0s 257ms/step
# preprocessed: dataset/data_vgg/cat//cat.174.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/cat//cat.175.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/cat//cat.176.jpg
# 1/1 [==============================] - 0s 257ms/step
# preprocessed: dataset/data_vgg/cat//cat.177.jpg
# 1/1 [==============================] - 0s 257ms/step
# preprocessed: dataset/data_vgg/cat//cat.178.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/cat//cat.179.jpg
# 1/1 [==============================] - 0s 271ms/step
# preprocessed: dataset/data_vgg/cat//cat.18.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/cat//cat.180.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/cat//cat.181.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/cat//cat.182.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/cat//cat.183.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/cat//cat.184.jpg
# 1/1 [==============================] - 0s 240ms/step
# preprocessed: dataset/data_vgg/cat//cat.185.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/cat//cat.186.jpg
# 1/1 [==============================] - 0s 240ms/step
# preprocessed: dataset/data_vgg/cat//cat.187.jpg
# 1/1 [==============================] - 0s 233ms/step
# preprocessed: dataset/data_vgg/cat//cat.188.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/cat//cat.189.jpg
# 1/1 [==============================] - 0s 241ms/step
# preprocessed: dataset/data_vgg/cat//cat.19.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/cat//cat.190.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/cat//cat.191.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/cat//cat.192.jpg
# 1/1 [==============================] - 0s 243ms/step
# preprocessed: dataset/data_vgg/cat//cat.193.jpg
# 1/1 [==============================] - 0s 240ms/step
# preprocessed: dataset/data_vgg/cat//cat.194.jpg
# 1/1 [==============================] - 0s 259ms/step
# preprocessed: dataset/data_vgg/cat//cat.195.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/cat//cat.196.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/cat//cat.197.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/cat//cat.198.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/cat//cat.199.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/cat//cat.2.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/cat//cat.20.jpg
# 1/1 [==============================] - 0s 243ms/step
# preprocessed: dataset/data_vgg/cat//cat.200.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/cat//cat.201.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/cat//cat.202.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/cat//cat.203.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/cat//cat.204.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/cat//cat.205.jpg
# 1/1 [==============================] - 0s 240ms/step
# preprocessed: dataset/data_vgg/cat//cat.206.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/cat//cat.207.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/cat//cat.208.jpg
# 1/1 [==============================] - 0s 239ms/step
# preprocessed: dataset/data_vgg/cat//cat.209.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/cat//cat.21.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/cat//cat.210.jpg
# 1/1 [==============================] - 0s 244ms/step
# preprocessed: dataset/data_vgg/cat//cat.211.jpg
# 1/1 [==============================] - 0s 244ms/step
# preprocessed: dataset/data_vgg/cat//cat.212.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/cat//cat.213.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/cat//cat.214.jpg
# 1/1 [==============================] - 0s 257ms/step
# preprocessed: dataset/data_vgg/cat//cat.215.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/cat//cat.216.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/cat//cat.217.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/cat//cat.218.jpg
# 1/1 [==============================] - 0s 262ms/step
# preprocessed: dataset/data_vgg/cat//cat.219.jpg
# 1/1 [==============================] - 0s 262ms/step
# preprocessed: dataset/data_vgg/cat//cat.22.jpg
# 1/1 [==============================] - 0s 260ms/step
# preprocessed: dataset/data_vgg/cat//cat.220.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/cat//cat.221.jpg
# 1/1 [==============================] - 0s 257ms/step
# preprocessed: dataset/data_vgg/cat//cat.222.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/cat//cat.223.jpg
# 1/1 [==============================] - 0s 244ms/step
# preprocessed: dataset/data_vgg/cat//cat.224.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/cat//cat.225.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/cat//cat.226.jpg
# 1/1 [==============================] - 0s 271ms/step
# preprocessed: dataset/data_vgg/cat//cat.227.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/cat//cat.228.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/cat//cat.229.jpg
# 1/1 [==============================] - 0s 239ms/step
# preprocessed: dataset/data_vgg/cat//cat.23.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/cat//cat.230.jpg
# 1/1 [==============================] - 0s 255ms/step
# preprocessed: dataset/data_vgg/cat//cat.231.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/cat//cat.232.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/cat//cat.233.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/cat//cat.234.jpg
# 1/1 [==============================] - 0s 243ms/step
# preprocessed: dataset/data_vgg/cat//cat.235.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/cat//cat.236.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/cat//cat.237.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/cat//cat.238.jpg
# 1/1 [==============================] - 0s 242ms/step
# preprocessed: dataset/data_vgg/cat//cat.239.jpg
# 1/1 [==============================] - 0s 233ms/step
# preprocessed: dataset/data_vgg/cat//cat.24.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/cat//cat.240.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/cat//cat.241.jpg
# 1/1 [==============================] - 0s 261ms/step
# preprocessed: dataset/data_vgg/cat//cat.242.jpg
# 1/1 [==============================] - 0s 242ms/step
# preprocessed: dataset/data_vgg/cat//cat.243.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/cat//cat.244.jpg
# 1/1 [==============================] - 0s 243ms/step
# preprocessed: dataset/data_vgg/cat//cat.245.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/cat//cat.246.jpg
# 1/1 [==============================] - 0s 239ms/step
# preprocessed: dataset/data_vgg/cat//cat.247.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/cat//cat.248.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/cat//cat.25.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/cat//cat.256.jpg
# 1/1 [==============================] - 0s 244ms/step
# preprocessed: dataset/data_vgg/cat//cat.26.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/cat//cat.264.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/cat//cat.27.jpg
# 1/1 [==============================] - 0s 260ms/step
# preprocessed: dataset/data_vgg/cat//cat.272.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/cat//cat.28.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/cat//cat.280.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/cat//cat.288.jpg
# 1/1 [==============================] - 0s 257ms/step
# preprocessed: dataset/data_vgg/cat//cat.29.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/cat//cat.296.jpg
# 1/1 [==============================] - 0s 244ms/step
# preprocessed: dataset/data_vgg/cat//cat.3.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/cat//cat.30.jpg
# 1/1 [==============================] - 0s 236ms/step
# preprocessed: dataset/data_vgg/cat//cat.304.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/cat//cat.31.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/cat//cat.312.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/cat//cat.32.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/cat//cat.320.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/cat//cat.328.jpg
# 1/1 [==============================] - 0s 260ms/step
# preprocessed: dataset/data_vgg/cat//cat.33.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/cat//cat.336.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/cat//cat.34.jpg
# 1/1 [==============================] - 0s 259ms/step
# preprocessed: dataset/data_vgg/cat//cat.344.jpg
# 1/1 [==============================] - 0s 272ms/step
# preprocessed: dataset/data_vgg/cat//cat.35.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/cat//cat.352.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/cat//cat.36.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/cat//cat.360.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/cat//cat.368.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/cat//cat.37.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/cat//cat.376.jpg
# 1/1 [==============================] - 0s 263ms/step
# preprocessed: dataset/data_vgg/cat//cat.38.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/cat//cat.384.jpg
# 1/1 [==============================] - 0s 265ms/step
# preprocessed: dataset/data_vgg/cat//cat.39.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/cat//cat.392.jpg
# 1/1 [==============================] - 0s 242ms/step
# preprocessed: dataset/data_vgg/cat//cat.4.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/cat//cat.40.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/cat//cat.400.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/cat//cat.408.jpg
# 1/1 [==============================] - 0s 237ms/step
# preprocessed: dataset/data_vgg/cat//cat.41.jpg
# 1/1 [==============================] - 0s 261ms/step
# preprocessed: dataset/data_vgg/cat//cat.416.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/cat//cat.42.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/cat//cat.424.jpg
# 1/1 [==============================] - 0s 258ms/step
# preprocessed: dataset/data_vgg/cat//cat.43.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/cat//cat.432.jpg
# 1/1 [==============================] - 0s 244ms/step
# preprocessed: dataset/data_vgg/cat//cat.44.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/cat//cat.440.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/cat//cat.448.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/cat//cat.45.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/cat//cat.456.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/cat//cat.46.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/cat//cat.464.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/cat//cat.47.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/cat//cat.472.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/cat//cat.48.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/cat//cat.480.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/cat//cat.488.jpg
# 1/1 [==============================] - 0s 271ms/step
# preprocessed: dataset/data_vgg/cat//cat.49.jpg
# 1/1 [==============================] - 0s 243ms/step
# preprocessed: dataset/data_vgg/cat//cat.496.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/cat//cat.5.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/cat//cat.50.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/cat//cat.504.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/cat//cat.51.jpg
# 1/1 [==============================] - 0s 238ms/step
# preprocessed: dataset/data_vgg/cat//cat.512.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/cat//cat.52.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/cat//cat.520.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/cat//cat.528.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/cat//cat.53.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/cat//cat.536.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/cat//cat.54.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/cat//cat.544.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/cat//cat.55.jpg
# 1/1 [==============================] - 0s 241ms/step
# preprocessed: dataset/data_vgg/cat//cat.552.jpg
# 1/1 [==============================] - 0s 258ms/step
# preprocessed: dataset/data_vgg/cat//cat.56.jpg
# 1/1 [==============================] - 0s 264ms/step
# preprocessed: dataset/data_vgg/cat//cat.560.jpg
# 1/1 [==============================] - 0s 257ms/step
# preprocessed: dataset/data_vgg/cat//cat.568.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/cat//cat.57.jpg
# 1/1 [==============================] - 0s 269ms/step
# preprocessed: dataset/data_vgg/cat//cat.576.jpg
# 1/1 [==============================] - 0s 259ms/step
# preprocessed: dataset/data_vgg/cat//cat.58.jpg
# 1/1 [==============================] - 0s 258ms/step
# preprocessed: dataset/data_vgg/cat//cat.584.jpg
# 1/1 [==============================] - 0s 275ms/step
# preprocessed: dataset/data_vgg/cat//cat.59.jpg
# 1/1 [==============================] - 0s 244ms/step
# preprocessed: dataset/data_vgg/cat//cat.592.jpg
# 1/1 [==============================] - 0s 260ms/step
# preprocessed: dataset/data_vgg/cat//cat.6.jpg
# 1/1 [==============================] - 0s 233ms/step
# preprocessed: dataset/data_vgg/cat//cat.60.jpg
# 1/1 [==============================] - 0s 266ms/step
# preprocessed: dataset/data_vgg/cat//cat.600.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/cat//cat.608.jpg
# 1/1 [==============================] - 0s 285ms/step
# preprocessed: dataset/data_vgg/cat//cat.61.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/cat//cat.616.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/cat//cat.62.jpg
# 1/1 [==============================] - 0s 241ms/step
# preprocessed: dataset/data_vgg/cat//cat.624.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/cat//cat.63.jpg
# 1/1 [==============================] - 0s 257ms/step
# preprocessed: dataset/data_vgg/cat//cat.632.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/cat//cat.64.jpg
# 1/1 [==============================] - 0s 240ms/step
# preprocessed: dataset/data_vgg/cat//cat.640.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/cat//cat.648.jpg
# 1/1 [==============================] - 0s 239ms/step
# preprocessed: dataset/data_vgg/cat//cat.65.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/cat//cat.656.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/cat//cat.66.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/cat//cat.664.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/cat//cat.67.jpg
# 1/1 [==============================] - 0s 243ms/step
# preprocessed: dataset/data_vgg/cat//cat.68.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/cat//cat.69.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/cat//cat.7.jpg
# 1/1 [==============================] - 0s 255ms/step
# preprocessed: dataset/data_vgg/cat//cat.70.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/cat//cat.71.jpg
# 1/1 [==============================] - 0s 258ms/step
# preprocessed: dataset/data_vgg/cat//cat.72.jpg
# 1/1 [==============================] - 0s 237ms/step
# preprocessed: dataset/data_vgg/cat//cat.73.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/cat//cat.74.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/cat//cat.75.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/cat//cat.76.jpg
# 1/1 [==============================] - 0s 239ms/step
# preprocessed: dataset/data_vgg/cat//cat.77.jpg
# 1/1 [==============================] - 0s 259ms/step
# preprocessed: dataset/data_vgg/cat//cat.78.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/cat//cat.79.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/cat//cat.8.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/cat//cat.80.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/cat//cat.81.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/cat//cat.82.jpg
# 1/1 [==============================] - 0s 244ms/step
# preprocessed: dataset/data_vgg/cat//cat.83.jpg
# 1/1 [==============================] - 0s 255ms/step
# preprocessed: dataset/data_vgg/cat//cat.84.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/cat//cat.85.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/cat//cat.86.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/cat//cat.87.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/cat//cat.88.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/cat//cat.89.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/cat//cat.9.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/cat//cat.90.jpg
# 1/1 [==============================] - 0s 255ms/step
# preprocessed: dataset/data_vgg/cat//cat.91.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/cat//cat.92.jpg
# 1/1 [==============================] - 0s 259ms/step
# preprocessed: dataset/data_vgg/cat//cat.93.jpg
# 1/1 [==============================] - 0s 258ms/step
# preprocessed: dataset/data_vgg/cat//cat.94.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/cat//cat.95.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/cat//cat.96.jpg
# 1/1 [==============================] - 0s 262ms/step
# preprocessed: dataset/data_vgg/cat//cat.97.jpg
# 1/1 [==============================] - 0s 243ms/step
# preprocessed: dataset/data_vgg/cat//cat.98.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/cat//cat.99.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.1.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/dog//dog.10.jpg
# 1/1 [==============================] - 0s 243ms/step
# preprocessed: dataset/data_vgg/dog//dog.100.jpg
# 1/1 [==============================] - 0s 259ms/step
# preprocessed: dataset/data_vgg/dog//dog.101.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.102.jpg
# 1/1 [==============================] - 0s 266ms/step
# preprocessed: dataset/data_vgg/dog//dog.103.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.104.jpg
# 1/1 [==============================] - 0s 229ms/step
# preprocessed: dataset/data_vgg/dog//dog.105.jpg
# 1/1 [==============================] - 0s 234ms/step
# preprocessed: dataset/data_vgg/dog//dog.106.jpg
# 1/1 [==============================] - 0s 236ms/step
# preprocessed: dataset/data_vgg/dog//dog.107.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/dog//dog.108.jpg
# 1/1 [==============================] - 0s 241ms/step
# preprocessed: dataset/data_vgg/dog//dog.109.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/dog//dog.11.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/dog//dog.110.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.111.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/dog//dog.112.jpg
# 1/1 [==============================] - 0s 244ms/step
# preprocessed: dataset/data_vgg/dog//dog.113.jpg
# 1/1 [==============================] - 0s 227ms/step
# preprocessed: dataset/data_vgg/dog//dog.114.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/dog//dog.115.jpg
# 1/1 [==============================] - 0s 231ms/step
# preprocessed: dataset/data_vgg/dog//dog.116.jpg
# 1/1 [==============================] - 0s 237ms/step
# preprocessed: dataset/data_vgg/dog//dog.117.jpg
# 1/1 [==============================] - 0s 238ms/step
# preprocessed: dataset/data_vgg/dog//dog.118.jpg
# 1/1 [==============================] - 0s 259ms/step
# preprocessed: dataset/data_vgg/dog//dog.119.jpg
# 1/1 [==============================] - 0s 241ms/step
# preprocessed: dataset/data_vgg/dog//dog.12.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/dog//dog.120.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/dog//dog.121.jpg
# 1/1 [==============================] - 0s 262ms/step
# preprocessed: dataset/data_vgg/dog//dog.122.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/dog//dog.123.jpg
# 1/1 [==============================] - 0s 255ms/step
# preprocessed: dataset/data_vgg/dog//dog.124.jpg
# 1/1 [==============================] - 0s 239ms/step
# preprocessed: dataset/data_vgg/dog//dog.125.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.126.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/dog//dog.127.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.128.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/dog//dog.129.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/dog//dog.13.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/dog//dog.130.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/dog//dog.131.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.132.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/dog//dog.133.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.134.jpg
# 1/1 [==============================] - 0s 255ms/step
# preprocessed: dataset/data_vgg/dog//dog.135.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/dog//dog.136.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.137.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/dog//dog.138.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/dog//dog.139.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/dog//dog.14.jpg
# 1/1 [==============================] - 0s 255ms/step
# preprocessed: dataset/data_vgg/dog//dog.140.jpg
# 1/1 [==============================] - 0s 264ms/step
# preprocessed: dataset/data_vgg/dog//dog.141.jpg
# 1/1 [==============================] - 0s 261ms/step
# preprocessed: dataset/data_vgg/dog//dog.142.jpg
# 1/1 [==============================] - 0s 228ms/step
# preprocessed: dataset/data_vgg/dog//dog.143.jpg
# 1/1 [==============================] - 0s 217ms/step
# preprocessed: dataset/data_vgg/dog//dog.144.jpg
# 1/1 [==============================] - 0s 231ms/step
# preprocessed: dataset/data_vgg/dog//dog.145.jpg
# 1/1 [==============================] - 0s 229ms/step
# preprocessed: dataset/data_vgg/dog//dog.146.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/dog//dog.147.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/dog//dog.148.jpg
# 1/1 [==============================] - 0s 257ms/step
# preprocessed: dataset/data_vgg/dog//dog.149.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.15.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/dog//dog.150.jpg
# 1/1 [==============================] - 0s 258ms/step
# preprocessed: dataset/data_vgg/dog//dog.151.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.152.jpg
# 1/1 [==============================] - 0s 257ms/step
# preprocessed: dataset/data_vgg/dog//dog.153.jpg
# 1/1 [==============================] - 0s 278ms/step
# preprocessed: dataset/data_vgg/dog//dog.154.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.155.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/dog//dog.156.jpg
# 1/1 [==============================] - 0s 266ms/step
# preprocessed: dataset/data_vgg/dog//dog.157.jpg
# 1/1 [==============================] - 0s 232ms/step
# preprocessed: dataset/data_vgg/dog//dog.158.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/dog//dog.159.jpg
# 1/1 [==============================] - 0s 261ms/step
# preprocessed: dataset/data_vgg/dog//dog.16.jpg
# 1/1 [==============================] - 0s 257ms/step
# preprocessed: dataset/data_vgg/dog//dog.160.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/dog//dog.161.jpg
# 1/1 [==============================] - 0s 255ms/step
# preprocessed: dataset/data_vgg/dog//dog.162.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/dog//dog.163.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/dog//dog.164.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/dog//dog.165.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.166.jpg
# 1/1 [==============================] - 0s 258ms/step
# preprocessed: dataset/data_vgg/dog//dog.167.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.168.jpg
# 1/1 [==============================] - 0s 242ms/step
# preprocessed: dataset/data_vgg/dog//dog.169.jpg
# 1/1 [==============================] - 0s 244ms/step
# preprocessed: dataset/data_vgg/dog//dog.17.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/dog//dog.170.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/dog//dog.171.jpg
# 1/1 [==============================] - 0s 240ms/step
# preprocessed: dataset/data_vgg/dog//dog.172.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/dog//dog.173.jpg
# 1/1 [==============================] - 0s 242ms/step
# preprocessed: dataset/data_vgg/dog//dog.174.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/dog//dog.175.jpg
# 1/1 [==============================] - 0s 257ms/step
# preprocessed: dataset/data_vgg/dog//dog.176.jpg
# 1/1 [==============================] - 0s 244ms/step
# preprocessed: dataset/data_vgg/dog//dog.177.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/dog//dog.178.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/dog//dog.179.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.18.jpg
# 1/1 [==============================] - 0s 236ms/step
# preprocessed: dataset/data_vgg/dog//dog.180.jpg
# 1/1 [==============================] - 0s 238ms/step
# preprocessed: dataset/data_vgg/dog//dog.181.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/dog//dog.182.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/dog//dog.183.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/dog//dog.184.jpg
# 1/1 [==============================] - 0s 258ms/step
# preprocessed: dataset/data_vgg/dog//dog.185.jpg
# 1/1 [==============================] - 0s 257ms/step
# preprocessed: dataset/data_vgg/dog//dog.186.jpg
# 1/1 [==============================] - 0s 241ms/step
# preprocessed: dataset/data_vgg/dog//dog.187.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/dog//dog.188.jpg
# 1/1 [==============================] - 0s 238ms/step
# preprocessed: dataset/data_vgg/dog//dog.189.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/dog//dog.19.jpg
# 1/1 [==============================] - 0s 258ms/step
# preprocessed: dataset/data_vgg/dog//dog.190.jpg
# 1/1 [==============================] - 0s 260ms/step
# preprocessed: dataset/data_vgg/dog//dog.191.jpg
# 1/1 [==============================] - 0s 261ms/step
# preprocessed: dataset/data_vgg/dog//dog.192.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.193.jpg
# 1/1 [==============================] - 0s 261ms/step
# preprocessed: dataset/data_vgg/dog//dog.194.jpg
# 1/1 [==============================] - 0s 260ms/step
# preprocessed: dataset/data_vgg/dog//dog.195.jpg
# 1/1 [==============================] - 0s 262ms/step
# preprocessed: dataset/data_vgg/dog//dog.196.jpg
# 1/1 [==============================] - 0s 262ms/step
# preprocessed: dataset/data_vgg/dog//dog.197.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.198.jpg
# 1/1 [==============================] - 0s 235ms/step
# preprocessed: dataset/data_vgg/dog//dog.199.jpg
# 1/1 [==============================] - 0s 233ms/step
# preprocessed: dataset/data_vgg/dog//dog.2.jpg
# 1/1 [==============================] - 0s 233ms/step
# preprocessed: dataset/data_vgg/dog//dog.20.jpg
# 1/1 [==============================] - 0s 264ms/step
# preprocessed: dataset/data_vgg/dog//dog.200.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/dog//dog.201.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.202.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.203.jpg
# 1/1 [==============================] - 0s 229ms/step
# preprocessed: dataset/data_vgg/dog//dog.204.jpg
# 1/1 [==============================] - 0s 270ms/step
# preprocessed: dataset/data_vgg/dog//dog.205.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/dog//dog.206.jpg
# 1/1 [==============================] - 0s 255ms/step
# preprocessed: dataset/data_vgg/dog//dog.207.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/dog//dog.208.jpg
# 1/1 [==============================] - 0s 260ms/step
# preprocessed: dataset/data_vgg/dog//dog.209.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/dog//dog.21.jpg
# 1/1 [==============================] - 0s 241ms/step
# preprocessed: dataset/data_vgg/dog//dog.210.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/dog//dog.211.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/dog//dog.212.jpg
# 1/1 [==============================] - 0s 258ms/step
# preprocessed: dataset/data_vgg/dog//dog.213.jpg
# 1/1 [==============================] - 0s 255ms/step
# preprocessed: dataset/data_vgg/dog//dog.214.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/dog//dog.215.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/dog//dog.216.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.217.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/dog//dog.218.jpg
# 1/1 [==============================] - 0s 255ms/step
# preprocessed: dataset/data_vgg/dog//dog.219.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.22.jpg
# 1/1 [==============================] - 0s 259ms/step
# preprocessed: dataset/data_vgg/dog//dog.220.jpg
# 1/1 [==============================] - 0s 265ms/step
# preprocessed: dataset/data_vgg/dog//dog.221.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/dog//dog.222.jpg
# 1/1 [==============================] - 0s 236ms/step
# preprocessed: dataset/data_vgg/dog//dog.223.jpg
# 1/1 [==============================] - 0s 240ms/step
# preprocessed: dataset/data_vgg/dog//dog.224.jpg
# 1/1 [==============================] - 0s 262ms/step
# preprocessed: dataset/data_vgg/dog//dog.225.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/dog//dog.226.jpg
# 1/1 [==============================] - 0s 239ms/step
# preprocessed: dataset/data_vgg/dog//dog.227.jpg
# 1/1 [==============================] - 0s 235ms/step
# preprocessed: dataset/data_vgg/dog//dog.228.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.229.jpg
# 1/1 [==============================] - 0s 243ms/step
# preprocessed: dataset/data_vgg/dog//dog.23.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/dog//dog.230.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/dog//dog.231.jpg
# 1/1 [==============================] - 0s 262ms/step
# preprocessed: dataset/data_vgg/dog//dog.232.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/dog//dog.233.jpg
# 1/1 [==============================] - 0s 243ms/step
# preprocessed: dataset/data_vgg/dog//dog.234.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/dog//dog.235.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.236.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.237.jpg
# 1/1 [==============================] - 0s 238ms/step
# preprocessed: dataset/data_vgg/dog//dog.238.jpg
# 1/1 [==============================] - 0s 237ms/step
# preprocessed: dataset/data_vgg/dog//dog.239.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.24.jpg
# 1/1 [==============================] - 0s 255ms/step
# preprocessed: dataset/data_vgg/dog//dog.240.jpg
# 1/1 [==============================] - 0s 257ms/step
# preprocessed: dataset/data_vgg/dog//dog.241.jpg
# 1/1 [==============================] - 0s 255ms/step
# preprocessed: dataset/data_vgg/dog//dog.242.jpg
# 1/1 [==============================] - 0s 262ms/step
# preprocessed: dataset/data_vgg/dog//dog.243.jpg
# 1/1 [==============================] - 0s 269ms/step
# preprocessed: dataset/data_vgg/dog//dog.244.jpg
# 1/1 [==============================] - 0s 265ms/step
# preprocessed: dataset/data_vgg/dog//dog.245.jpg
# 1/1 [==============================] - 0s 259ms/step
# preprocessed: dataset/data_vgg/dog//dog.246.jpg
# 1/1 [==============================] - 0s 262ms/step
# preprocessed: dataset/data_vgg/dog//dog.247.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/dog//dog.248.jpg
# 1/1 [==============================] - 0s 273ms/step
# preprocessed: dataset/data_vgg/dog//dog.249.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/dog//dog.25.jpg
# 1/1 [==============================] - 0s 262ms/step
# preprocessed: dataset/data_vgg/dog//dog.250.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/dog//dog.251.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/dog//dog.252.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/dog//dog.253.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/dog//dog.254.jpg
# 1/1 [==============================] - 0s 255ms/step
# preprocessed: dataset/data_vgg/dog//dog.255.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/dog//dog.256.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/dog//dog.257.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.258.jpg
# 1/1 [==============================] - 0s 258ms/step
# preprocessed: dataset/data_vgg/dog//dog.259.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/dog//dog.26.jpg
# 1/1 [==============================] - 0s 238ms/step
# preprocessed: dataset/data_vgg/dog//dog.260.jpg
# 1/1 [==============================] - 0s 232ms/step
# preprocessed: dataset/data_vgg/dog//dog.261.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/dog//dog.262.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.263.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/dog//dog.264.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.265.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/dog//dog.266.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/dog//dog.267.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/dog//dog.268.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/dog//dog.269.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.27.jpg
# 1/1 [==============================] - 0s 242ms/step
# preprocessed: dataset/data_vgg/dog//dog.270.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/dog//dog.271.jpg
# 1/1 [==============================] - 0s 242ms/step
# preprocessed: dataset/data_vgg/dog//dog.272.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/dog//dog.273.jpg
# 1/1 [==============================] - 0s 257ms/step
# preprocessed: dataset/data_vgg/dog//dog.274.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/dog//dog.275.jpg
# 1/1 [==============================] - 0s 260ms/step
# preprocessed: dataset/data_vgg/dog//dog.276.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/dog//dog.277.jpg
# 1/1 [==============================] - 0s 265ms/step
# preprocessed: dataset/data_vgg/dog//dog.278.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/dog//dog.279.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/dog//dog.28.jpg
# 1/1 [==============================] - 0s 263ms/step
# preprocessed: dataset/data_vgg/dog//dog.280.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/dog//dog.281.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/dog//dog.282.jpg
# 1/1 [==============================] - 0s 244ms/step
# preprocessed: dataset/data_vgg/dog//dog.283.jpg
# 1/1 [==============================] - 0s 273ms/step
# preprocessed: dataset/data_vgg/dog//dog.284.jpg
# 1/1 [==============================] - 0s 259ms/step
# preprocessed: dataset/data_vgg/dog//dog.285.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.286.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/dog//dog.287.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/dog//dog.288.jpg
# 1/1 [==============================] - 0s 262ms/step
# preprocessed: dataset/data_vgg/dog//dog.289.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/dog//dog.29.jpg
# 1/1 [==============================] - 0s 272ms/step
# preprocessed: dataset/data_vgg/dog//dog.290.jpg
# 1/1 [==============================] - 0s 269ms/step
# preprocessed: dataset/data_vgg/dog//dog.291.jpg
# 1/1 [==============================] - 0s 260ms/step
# preprocessed: dataset/data_vgg/dog//dog.292.jpg
# 1/1 [==============================] - 0s 265ms/step
# preprocessed: dataset/data_vgg/dog//dog.293.jpg
# 1/1 [==============================] - 0s 258ms/step
# preprocessed: dataset/data_vgg/dog//dog.294.jpg
# 1/1 [==============================] - 0s 259ms/step
# preprocessed: dataset/data_vgg/dog//dog.295.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.296.jpg
# 1/1 [==============================] - 0s 276ms/step
# preprocessed: dataset/data_vgg/dog//dog.297.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.298.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/dog//dog.299.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/dog//dog.3.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/dog//dog.30.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/dog//dog.300.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.31.jpg
# 1/1 [==============================] - 0s 255ms/step
# preprocessed: dataset/data_vgg/dog//dog.32.jpg
# 1/1 [==============================] - 0s 236ms/step
# preprocessed: dataset/data_vgg/dog//dog.33.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/dog//dog.34.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/dog//dog.35.jpg
# 1/1 [==============================] - 0s 243ms/step
# preprocessed: dataset/data_vgg/dog//dog.36.jpg
# 1/1 [==============================] - 0s 240ms/step
# preprocessed: dataset/data_vgg/dog//dog.37.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.38.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/dog//dog.39.jpg
# 1/1 [==============================] - 0s 255ms/step
# preprocessed: dataset/data_vgg/dog//dog.4.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/dog//dog.40.jpg
# 1/1 [==============================] - 0s 261ms/step
# preprocessed: dataset/data_vgg/dog//dog.41.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/dog//dog.42.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/dog//dog.43.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/dog//dog.44.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.45.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/dog//dog.46.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/dog//dog.47.jpg
# 1/1 [==============================] - 0s 255ms/step
# preprocessed: dataset/data_vgg/dog//dog.48.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.49.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/dog//dog.5.jpg
# 1/1 [==============================] - 0s 244ms/step
# preprocessed: dataset/data_vgg/dog//dog.50.jpg
# 1/1 [==============================] - 0s 243ms/step
# preprocessed: dataset/data_vgg/dog//dog.51.jpg
# 1/1 [==============================] - 0s 257ms/step
# preprocessed: dataset/data_vgg/dog//dog.52.jpg
# 1/1 [==============================] - 0s 243ms/step
# preprocessed: dataset/data_vgg/dog//dog.53.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/dog//dog.54.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/dog//dog.55.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.56.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/dog//dog.57.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.58.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/dog//dog.59.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.6.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/dog//dog.60.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.61.jpg
# 1/1 [==============================] - 0s 258ms/step
# preprocessed: dataset/data_vgg/dog//dog.62.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.63.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/dog//dog.64.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.65.jpg
# 1/1 [==============================] - 0s 260ms/step
# preprocessed: dataset/data_vgg/dog//dog.66.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/dog//dog.67.jpg
# 1/1 [==============================] - 0s 249ms/step
# preprocessed: dataset/data_vgg/dog//dog.68.jpg
# 1/1 [==============================] - 0s 272ms/step
# preprocessed: dataset/data_vgg/dog//dog.69.jpg
# 1/1 [==============================] - 0s 267ms/step
# preprocessed: dataset/data_vgg/dog//dog.7.jpg
# 1/1 [==============================] - 0s 275ms/step
# preprocessed: dataset/data_vgg/dog//dog.70.jpg
# 1/1 [==============================] - 0s 265ms/step
# preprocessed: dataset/data_vgg/dog//dog.71.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/dog//dog.72.jpg
# 1/1 [==============================] - 0s 264ms/step
# preprocessed: dataset/data_vgg/dog//dog.73.jpg
# 1/1 [==============================] - 0s 279ms/step
# preprocessed: dataset/data_vgg/dog//dog.74.jpg
# 1/1 [==============================] - 0s 255ms/step
# preprocessed: dataset/data_vgg/dog//dog.75.jpg
# 1/1 [==============================] - 0s 257ms/step
# preprocessed: dataset/data_vgg/dog//dog.76.jpg
# 1/1 [==============================] - 0s 254ms/step
# preprocessed: dataset/data_vgg/dog//dog.77.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/dog//dog.78.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.79.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/dog//dog.8.jpg
# 1/1 [==============================] - 0s 242ms/step
# preprocessed: dataset/data_vgg/dog//dog.80.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.81.jpg
# 1/1 [==============================] - 0s 252ms/step
# preprocessed: dataset/data_vgg/dog//dog.82.jpg
# 1/1 [==============================] - 0s 231ms/step
# preprocessed: dataset/data_vgg/dog//dog.83.jpg
# 1/1 [==============================] - 0s 238ms/step
# preprocessed: dataset/data_vgg/dog//dog.84.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/dog//dog.85.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/dog//dog.86.jpg
# 1/1 [==============================] - 0s 256ms/step
# preprocessed: dataset/data_vgg/dog//dog.87.jpg
# 1/1 [==============================] - 0s 244ms/step
# preprocessed: dataset/data_vgg/dog//dog.88.jpg
# 1/1 [==============================] - 0s 250ms/step
# preprocessed: dataset/data_vgg/dog//dog.89.jpg
# 1/1 [==============================] - 0s 245ms/step
# preprocessed: dataset/data_vgg/dog//dog.9.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/dog//dog.90.jpg
# 1/1 [==============================] - 0s 237ms/step
# preprocessed: dataset/data_vgg/dog//dog.91.jpg
# 1/1 [==============================] - 0s 246ms/step
# preprocessed: dataset/data_vgg/dog//dog.92.jpg
# 1/1 [==============================] - 0s 251ms/step
# preprocessed: dataset/data_vgg/dog//dog.93.jpg
# 1/1 [==============================] - 0s 253ms/step
# preprocessed: dataset/data_vgg/dog//dog.94.jpg
# 1/1 [==============================] - 0s 243ms/step
# preprocessed: dataset/data_vgg/dog//dog.95.jpg
# 1/1 [==============================] - 0s 247ms/step
# preprocessed: dataset/data_vgg/dog//dog.96.jpg
# 1/1 [==============================] - 0s 248ms/step
# preprocessed: dataset/data_vgg/dog//dog.97.jpg
# 1/1 [==============================] - 0s 239ms/step
# preprocessed: dataset/data_vgg/dog//dog.98.jpg
# 1/1 [==============================] - 0s 239ms/step
# preprocessed: dataset/data_vgg/dog//dog.99.jpg
# (300, 25088) (300, 25088)
# (600, 25088) (600, 1)
